# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersontm2/IA_ULEAM/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
ridership=pd.read_csv(url)
ridership.head
# Out:
# <bound method NDFrame.head of          station_id        stationname        date daytype  rides
# 0             41280     Jefferson Park  12/22/2017       W   6104
# 1             41000   Cermak-Chinatown  12/18/2017       W   3636
# 2             40280       Central-Lake  12/02/2017       A   1270
# 3             40140    Dempster-Skokie  12/19/2017       W   1759
# 4             40690           Dempster  12/03/2017       U    499
# ...             ...                ...         ...     ...    ...
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# [1145586 rows x 5 columns]>

# %% [markdown]
# for basic exploration, we suggest to use shape, head(), tail(), dtypes, type() modules

# %%
print("Shape of the DataFrame:", df.shape)
print()

print("First few rows of the DataFrame:")
print(df.head())
print()

print("Last few rows of the DataFrame:")
print(df.tail())
print()

print("Data types of each column:")
print(df.dtypes)
print()

print("Type of the DataFrame:", type(df))
# Out:
# Shape of the DataFrame: (1145586, 5)
#
# First few rows of the DataFrame:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499
#
# Last few rows of the DataFrame:
#          station_id        stationname        date daytype  rides
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# Data types of each column:
# station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object
#
# Type of the DataFrame: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# use the describe module

# %%
description = df.describe()

print("Statistical summary of the DataFrame:")
print(description)
# Out:
# Statistical summary of the DataFrame:
#          station_id         rides
# count  1.145586e+06  1.145586e+06
# mean   4.076649e+04  3.056635e+03
# std    4.490665e+02  3.118576e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.630000e+02
# 50%    4.076000e+04  2.004000e+03
# 75%    4.115000e+04  4.025000e+03
# max    4.170000e+04  3.632300e+04

# %% [markdown]
# use the min() and max() modules

# %%
min_value = df['station_id'].min()
print("Minimum value:", min_value)

min_value = df['stationname'].min()
print("Minimum value:", min_value)

min_value = df['date'].min()
print("Minimum value:", min_value)

min_value = df['daytype'].min()
print("Minimum value:", min_value)

min_value = df['rides'].min()
print("Minimum value:", min_value)

max_value = df['station_id'].max()
print("Maximum value:", max_value)

max_value = df['stationname'].max()
print("Maximum value:", max_value)

max_value = df['date'].max()
print("Maximum value:", max_value)

max_value = df['daytype'].max()
print("Maximum value:", max_value)

max_value = df['rides'].max()
print("Maximum value:", max_value)
# Out:
# Minimum value: 40010
# Minimum value: 18th
# Minimum value: 01/01/2001
# Minimum value: A
# Minimum value: 0
# Maximum value: 41700
# Maximum value: Wilson
# Maximum value: 12/31/2022
# Maximum value: W
# Maximum value: 36323

# %% [markdown]
# hint, use to_datetime() and set_index()  modules

# %%
df['date'] = pd.to_datetime(df['date'])

df.set_index('date', inplace=True)

print(df)
# Out:
#             station_id        stationname daytype  rides
# date
# 2017-12-22       41280     Jefferson Park       W   6104
# 2017-12-18       41000   Cermak-Chinatown       W   3636
# 2017-12-02       40280       Central-Lake       A   1270
# 2017-12-19       40140    Dempster-Skokie       W   1759
# 2017-12-03       40690           Dempster       U    499
# ...                ...                ...     ...    ...
# 2022-12-27       41700  Washington/Wabash       W   3991
# 2022-12-28       41700  Washington/Wabash       W   4100
# 2022-12-29       41700  Washington/Wabash       W   4741
# 2022-12-30       41700  Washington/Wabash       W   4664
# 2022-12-31       41700  Washington/Wabash       A   2774
#
# [1145586 rows x 4 columns]

# %% [markdown]
# hint, sort_values(by='date')

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
df = pd.read_csv(url)
df['date'] = pd.to_datetime(df['date'])

df = df.sort_values(by='date')

print(df)
# Out:
#          station_id         stationname       date daytype  rides
# 745112        41290             Kimball 2001-01-01       U    869
# 290203        40090         Damen-Brown 2001-01-01       U    411
# 848027        40850             Library 2001-01-01       U    156
# 1072423       40650      North/Clybourn 2001-01-01       U   1156
# 885492        40290        Ashland/63rd 2001-01-01       U    540
# ...             ...                 ...        ...     ...    ...
# 1145461       41660          Lake/State 2022-12-31       A   5491
# 1144004       41000    Cermak-Chinatown 2022-12-31       A   2055
# 1142330       40400               Noyes 2022-12-31       A    121
# 1143911       40970  Cicero-Forest Park 2022-12-31       A    349
# 1145585       41700   Washington/Wabash 2022-12-31       A   2774
#
# [1145586 rows x 5 columns]

# %% [markdown]
# hint, use filter like, df['stationname']=='Garfield-Dan Ryan']
# use the following variable name for your specific stations
# Garfield_Dan_Ryan=pd.DataFrame()

# %%
Garfield_Dan_Ryan = df[df['stationname'] == 'Garfield-Dan Ryan']

print(Garfield_Dan_Ryan)
# Out:
#          station_id        stationname       date daytype  rides
# 482090        41170  Garfield-Dan Ryan 2001-01-01       U   1457
# 656150        41170  Garfield-Dan Ryan 2001-01-02       W   3748
# 531339        41170  Garfield-Dan Ryan 2001-01-03       W   3977
# 591338        41170  Garfield-Dan Ryan 2001-01-04       W   4185
# 484927        41170  Garfield-Dan Ryan 2001-01-05       W   4533
# ...             ...                ...        ...     ...    ...
# 1144465       41170  Garfield-Dan Ryan 2022-12-27       W    976
# 1144466       41170  Garfield-Dan Ryan 2022-12-28       W    961
# 1144467       41170  Garfield-Dan Ryan 2022-12-29       W    991
# 1144468       41170  Garfield-Dan Ryan 2022-12-30       W   1135
# 1144469       41170  Garfield-Dan Ryan 2022-12-31       A    776
#
# [8005 rows x 5 columns]

# %% [markdown]
# hint, use filter like this df['stationname']=='Garfield-South Elevated']
# your code here
# use the following variable name for your specific stations
# Garfield_South_Elevated=pd.DataFrame()

# %%
Garfield_South_Elevated = df[df['stationname'] == 'Garfield-South Elevated']

print(Garfield_South_Elevated)
# Out:
#          station_id              stationname       date daytype  rides
# 424117        40510  Garfield-South Elevated 2001-01-01       U    248
# 503414        40510  Garfield-South Elevated 2001-01-02       W    617
# 253834        40510  Garfield-South Elevated 2001-01-03       W    657
# 707802        40510  Garfield-South Elevated 2001-01-04       W    697
# 898326        40510  Garfield-South Elevated 2001-01-05       W    770
# ...             ...                      ...        ...     ...    ...
# 1142605       40510  Garfield-South Elevated 2022-12-27       W    384
# 1142606       40510  Garfield-South Elevated 2022-12-28       W    436
# 1142607       40510  Garfield-South Elevated 2022-12-29       W    448
# 1142608       40510  Garfield-South Elevated 2022-12-30       W    472
# 1142609       40510  Garfield-South Elevated 2022-12-31       A    249
#
# [8035 rows x 5 columns]

# %% [markdown]
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# sns.set(rc={'figure.figsize':(11, 4)})
# Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(11, 4)})
Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)

plt.xlabel('Date')
plt.ylabel('Rides')
plt.title('Rides over Time - Garfield-Dan Ryan Station')

plt.show()

# %% [markdown]
# sns.set(rc={'figure.figsize':(11, 4)})
# Garfield_South_Elevated['rides'].plot(linewidth=0.5)

# %%
sns.set(rc={'figure.figsize':(11, 4)})
Garfield_South_Elevated['rides'].plot(linewidth=0.5)

plt.xlabel('Date')
plt.ylabel('Rides')
plt.title('Rides over Time - Garfield-South Elevated Station')

plt.show()

# %%
column_names = df.columns

# Mostrar los nombres de las columnas
print("Nombres de las columnas:")
print(column_names)
# Out:
# Nombres de las columnas:
# Index(['station_id', 'stationname', 'date', 'daytype', 'rides'], dtype='object')
